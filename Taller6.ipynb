# %%
import math
#Adrián Parra

angle=0
suma=0
ea=5
es=(0.5*(10**-8))
n=0
print("Este programa solicita un angulo y entrega el resultado de Cos(X) con menor porcentaje de error")
clase=str(input("Quieres ingresar el angulo en radianes o grados: "))
clase=clase.lower()

if clase == "radianes":
    print("Ingrese un angulo en radianes de la forma Xπ/n")
    x=int(input("Ingrese el X de los radianes: "))
    n=int(input("Ingrese el n de los radianes: "))
    angle=(x*math.pi)/n
    print(f"{angle} radianes")
elif clase == "grados":
    print("Ingrese un angulo en grados")
    angle=float(input("Ingrese el angulo: "))
    angle=(angle*math.pi)/180
    print("El angulo se pasara a radianes")
    print(f"{angle} radianes")
else:
    print("Ingrese una opcion valida")
    clase=str(input("Quieres ingresar el angulo en radianes o grados: "))
    
opcion=str(input("Quieres imprimir solo la respuesta (S/N): "))
opcion=opcion.lower()

if opcion=="s" or opcion=="si":
  while ea>es:
    coseno=((-1)**n)*((angle**n)/math.factorial(n))
    suma+=coseno      
    if suma!=0:
      ea=abs((coseno/suma)*100)
      ea=round(ea,8)        
    n+=1
  print(f"Total: {suma}")
  print("Porcentaje de error final ",ea,"%")
  print("El numero de iteraciones totales es de:",n)
else:
  while ea>es:
    print(f"Cos({(round(angle,2))})= {suma}")
    coseno=((-1)**n)*((angle**n)/math.factorial(n))
    suma+=coseno
    print("Valor estimado: ",suma)
    if suma!=0:
      ea=abs((coseno/suma)*100)
      ea=round(ea,8)
      print("El error aproximado relativo en porcentaje es: ",ea, "%")
    n+=1
    print("Iteración número: ",n)
# Out:
# Este programa solicita un angulo y entrega el resultado de Cos(X) con menor porcentaje de error
# Quieres ingresar el angulo en radianes o grados: grados
# Ingrese un angulo en grados
# Ingrese el angulo: 45
# El angulo se pasara a radianes
# 0.7853981633974483 radianes
# Quieres imprimir solo la respuesta (S/N): n
# Cos(0.79)= 0
# Valor estimado:  1.0
# El error aproximado relativo en porcentaje es:  100.0 %
# Iteración número:  1
# Cos(0.79)= 1.0
# Valor estimado:  0.21460183660255172
# El error aproximado relativo en porcentaje es:  365.97923663 %
# Iteración número:  2
# Cos(0.79)= 0.21460183660255172
# Valor estimado:  0.5230269741365942
# El error aproximado relativo en porcentaje es:  58.96926025 %
# Iteración número:  3
# Cos(0.79)= 0.5230269741365942
# Valor estimado:  0.4422814619483134
# El error aproximado relativo en porcentaje es:  18.25658978 %
# Iteración número:  4
# Cos(0.79)= 0.4422814619483134
# Valor estimado:  0.4581358061921289
# El error aproximado relativo en porcentaje es:  3.46062107 %
# Iteración número:  5
# Cos(0.79)= 0.4581358061921289
# Valor estimado:  0.45564541162193617
# El error aproximado relativo en porcentaje es:  0.54656417 %
# Iteración número:  6
# Cos(0.79)= 0.45564541162193617
# Valor estimado:  0.45597140350886356
# El error aproximado relativo en porcentaje es:  0.07149393 %
# Iteración número:  7
# Cos(0.79)= 0.45597140350886356
# Valor estimado:  0.4559348273046814
# El error aproximado relativo en porcentaje es:  0.00802224 %
# Iteración número:  8
# Cos(0.79)= 0.4559348273046814
# Valor estimado:  0.45593841816513
# El error aproximado relativo en porcentaje es:  0.00078758 %
# Iteración número:  9
# Cos(0.79)= 0.45593841816513
# Valor estimado:  0.45593810480344094
# El error aproximado relativo en porcentaje es:  6.873e-05 %
# Iteración número:  10
# Cos(0.79)= 0.45593810480344094
# Valor estimado:  0.45593812941481043
# El error aproximado relativo en porcentaje es:  5.4e-06 %
# Iteración número:  11
# Cos(0.79)= 0.45593812941481043
# Valor estimado:  0.45593812765756275
# El error aproximado relativo en porcentaje es:  3.9e-07 %
# Iteración número:  12
# Cos(0.79)= 0.45593812765756275
# Valor estimado:  0.45593812777257436
# El error aproximado relativo en porcentaje es:  3e-08 %
# Iteración número:  13
# Cos(0.79)= 0.45593812777257436
# Valor estimado:  0.4559381277656259
# El error aproximado relativo en porcentaje es:  0.0 %
# Iteración número:  14
